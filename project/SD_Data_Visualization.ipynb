# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/final_df.csv')

# %%
df.sort_values('roi', ascending=False)
# Out:
#       Unnamed: 0 release_date  production_budget_x  worldwide_gross  \
# 0              0   2015-07-10               100000         41656474
# 37            37   2012-01-06              1000000        101759490
# 109          109   2011-04-01              1500000         99870886
# 118          118   2015-04-17              1000000         64364198
# 38            38   2010-10-20              3000000        177512032
# 119          119   2017-01-20              5000000        278964806
# 120          120   2017-02-24              5000000        255367951
# 233          233   2012-05-25              1000000         42411721
# 39            39   2011-10-21              5000000        207039844
# 1              1   2014-10-03              6500000        256862920
# 334          334   2010-08-27              1800000         70165900
# 110          110   2013-09-13              5000000        161921515
# 395          395   2016-12-21              9500000        294654618
# ...

# %%
df.sort_values('production_budget_x', ascending=False)
# Out:
#       Unnamed: 0 release_date  production_budget_x  worldwide_gross  \
# 1057        1057   2011-05-20            410600000       1045663875
# 1036        1036   2015-05-01            330600000       1403013963
# 1017        1017   2018-04-27            300000000       2048134200
# 280          280   2017-11-17            300000000        655945209
# 857          857   2015-11-06            300000000        879620923
# 1081        1081   2013-07-02            275000000        260002115
# 253          253   2012-07-20            275000000       1084439099
# 1070        1070   2018-05-25            275000000        393151347
# 1080        1080   2012-03-09            275000000        282778100
# 1059        1059   2010-11-24            260000000        586477240
# 161          161   2017-04-14            250000000       1234846267
# 257          257   2016-03-25            250000000        867500281
# 18            18   2013-12-13            250000000        960366855
# ...

# %%
sns.lmplot(x='production_budget_x', y='worldwide_gross', data=df, hue='studio_size', markers=["1", "x", "o"],
           height=8, aspect=2, legend=False);
plt.legend(loc='upper left');
# Out:
# /Users/stevedye/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Production budget of each movie vs. the worldwide gross

# %%
sns.lmplot(x='production_budget_x', y='roi', data=df, hue='studio_size', markers=["1", "x", "o"],
           height=8, aspect=2, legend=False);
plt.legend(loc='upper right');
# Out:
# /Users/stevedye/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(16, 10))
sns.regplot(x=df['production_budget_x'], y=df['roi'], fit_reg=False);

# %% [markdown]
# Larger studios have a larger mean ROI

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(y=df['studio_size'], x=df['production_budget_x']);

# %% [markdown]
# Larger movie studios spent more money making movies and make more of them.

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(y=df['studio_size'], x=df['roi']);

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(y=df['studio_size'], x=df['net_revenue']);
