# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/final_df.csv')

# %%
df.sort_values('roi', ascending=False)
# Out:
#       Unnamed: 0 release_date  production_budget_x  worldwide_gross  \
# 562          562   2015-07-10               100000         41656474
# 596          596   2012-01-06              1000000        101759490
# 1006        1006   2011-04-01              1500000         99870886
# 73            73   2015-04-17              1000000         64364198
# 582          582   2010-10-20              3000000        177512032
# 100          100   2017-01-20              5000000        278964806
# 103          103   2017-02-24              5000000        255367951
# 272          272   2012-05-25              1000000         42411721
# 592          592   2011-10-21              5000000        207039844
# 558          558   2014-10-03              6500000        256862920
# 127          127   2010-08-27              1800000         70165900
# 1014        1014   2013-09-13              5000000        161921515
# 931          931   2016-12-21              9500000        294654618
# ...

# %%
df.sort_values('production_budget_x', ascending=False)
# Out:
#       Unnamed: 0 release_date  production_budget_x  worldwide_gross  \
# 788          788   2011-05-20            410600000       1045663875
# 821          821   2015-05-01            330600000       1403013963
# 844          844   2018-04-27            300000000       2048134200
# 328          328   2017-11-17            300000000        655945209
# 717          717   2015-11-06            300000000        879620923
# 274          274   2012-07-20            275000000       1084439099
# 795          795   2012-03-09            275000000        282778100
# 845          845   2018-05-25            275000000        393151347
# 804          804   2013-07-02            275000000        260002115
# 784          784   2010-11-24            260000000        586477240
# 829          829   2016-05-06            250000000       1140069413
# 104          104   2017-04-14            250000000       1234846267
# 550          550   2012-12-14            250000000       1017003568
# ...

# %%
sns.set(font_scale=2)
ax = sns.lmplot(x='production_budget_x', y='worldwide_gross', data=df,
                hue='studio_size', markers=["1", "x", "o"], height=10,
                aspect=1.75, legend=False)
plt.xlim(0, None)
plt.ylim(0, None)
plt.xlabel('Production Budget')
plt.ylabel('Worldwide Gross')
plt.legend(loc='upper left', title_fontsize='24', title='Studio Size');
# Out:
# /Users/stevedye/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Let's zoom in.

# %%
sns.set(font_scale=2)
sns.lmplot(x='production_budget_x', y='worldwide_gross', data=df,
           hue='studio_size', markers=["1", "x", "o"],
           height=10, aspect=1.75, legend=False)
plt.xlim(0, 10**8)
plt.ylim(0, 5*10**8)
plt.xlabel('Production Budget')
plt.ylabel('Worldwide Gross')
plt.legend(loc='upper left', title_fontsize='24',
           title='Studio Size');
# Out:
# /Users/stevedye/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Obvious rounding artificats.

# %% [markdown]
# Production budget of each movie vs. the worldwide gross.

# %%
sns.set(font_scale=1.5)
sns.lmplot(x='log_prod_bud', y='log_roi', data=df,
           hue='studio_size', markers=["*", ",", "o"],
           height=5, aspect=2, legend=False,
           fit_reg=False, scatter_kws={"s": 50})
plt.xlabel('Log of Production Budget')
plt.ylabel('Log of ROI')
plt.legend(loc='lower left', title='Studio Size');

# %% [markdown]
# ### Take a closer look.

# %%
sns.set(font_scale=2)
sns.lmplot(x='production_budget_x', y='roi', data=df,
           hue='studio_size', markers=["1", "x", "o"],
           height=10, aspect=1.75, legend=False);
plt.xlim(0, 10**8)
plt.ylim(-5, 110)
plt.xlabel('Production Budget')
plt.ylabel('ROI')
plt.legend(title_fontsize='24', title='Studio Size');
# Out:
# /Users/stevedye/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(16, 10))
sns.regplot(x=df['production_budget_x'], y=df['roi'],
            fit_reg=False);

# %% [markdown]
# Larger studios have a larger mean ROI

# %%
sns.set(font_scale=2)
plt.figure(figsize=(16, 8))
sns.boxplot(y=df['studio_size'], x=df['production_budget_x'])
plt.xlabel('Production Budget')
plt.ylabel('Studio Size');

# %% [markdown]
# Larger movie studios spent more money making movies and make more of them.

# %%
sns.set(font_scale=2)
plt.figure(figsize=(16, 8))
sns.boxplot(y=df['studio_size'], x=df['roi'])
plt.xlabel('ROI')
plt.ylabel('Studio Size');

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(8, 4))
sns.boxplot(y=df['studio_size'], x=df['roi'])
plt.xlim(-2, 104)
plt.xlabel('ROI')
plt.ylabel('Studio Size');

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(10, 5))
sns.boxplot(y=df['studio_size'], x=df['roi'])
plt.xlim(-2, 65)
plt.xlabel('ROI')
plt.ylabel('Studio Size');

# %% [markdown]
# Not pictured: the ROI value near 400.

# %%
sns.set(font_scale=2)
plt.figure(figsize=(16, 8))
sns.boxplot(y=df['studio_size'], x=df['worldwide_gross'])
plt.xlabel('Worldwide Gross')
plt.ylabel('Studio Size');

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(8, 4))
sns.barplot(x=df['movie_budget_size'], y=df['roi'],
            palette='husl', ci=None)
plt.xlabel('Movie Budget')
plt.ylabel('ROI');

# %%
sns.set(font_scale=1.5)
plt.figure(figsize=(8, 4))
sns.barplot(x='movie_budget_size', y='roi', data=df,
            hue='studio_size',ci=None)
plt.xlabel('Movie Budget')
plt.ylabel('ROI')
plt.legend(loc='upper left', title='Studio Size');
